# %% [markdown]
# ## Loops

# %%
# Question 1
# Use a for loop with range() to print even numbers from 2 to 10.

# Write your code here

# %%
# Question 2
# Use a loop to add up all the numbers in the list: [5, 10, 15, 20]

nums = [5, 10, 15, 20]

# Write your code here

# %%
# Question 3
# Loop through the dictionary and print each key.

student = {'name': 'Alice', 'age': 21, 'grade': 'A'}

# Write your code here

# %%
# Question 4
# Loop through the dictionary and print each value.

# Write your code here

# %%
# Question 5
# Loop through the dictionary and print both key and value using .items()

# Write your code here

# %%
# Question 6
# Loop through this list: [2, 3, 4, 5, 6, 7, 8, 9, 10]
# Print "Even" for even element and "Odd" for each odd element

# Write your code here

# %%
# Question 7
# Split the string into a list using .split() and print the first character of each word
text = "Learning python is fun yet challenging"

# Write your code here

# %%
# Question 8
# Ask the user to enter a number repeatedly until they type 0.
# Then print the sum of all entered numbers (excluding the 0).

# Hint: Use input(), convert to int, and use a loop

# Write your code here

# %%
# Question 9
# Use a while loop to find the first number greater than 0 that is divisible by both 3 and 5.
# Start checking from 1.

# Write your code here
