# %% [markdown]
# ## List Comprehensions

# %%
# Question 1
# Use list comprehension to create a list of squares from 1 to 10.
# Output: [1, 4, 9, ..., 100]

# Write your code here

# %%
# Question 2
# Use list comprehension to create a list of even numbers between 1 and 20.

# Write your code here

# %%
# Question 3
# Given a list: [1, -2, 3, -4, 5],
# Use list comprehension to create a new list containing only the positive numbers.

numbers = [1, -2, 3, -4, 5]

# Write your code here

# %%
# Question 4
# Use list comprehension to extract the first character of each word in this list:
# ['apple', 'banana', 'cherry'] → ['a', 'b', 'c']

words = ['apple', 'banana', 'cherry']

# Write your code here

# %% [markdown]
# ## Dictionary Comprehensions

# %%
# Question 5
# Create a dictionary using dictionary comprehension that maps numbers 1 to 5
# to their squares.
# Output: {1: 1, 2: 4, 3: 9, ...}

# Write your code here

# %%
# Question 6
# Given a dictionary of items and their prices:
# items = {'apple': 50, 'banana': 30, 'cherry': 20}
# Use dictionary comprehension to create a new dictionary with prices doubled.

items = {'apple': 50, 'banana': 30, 'cherry': 20}

# Write your code here

# %%
# Question 7
# Given a dictionary with student names and marks:
# students = {'Alice': 85, 'Bob': 60, 'Charlie': 95}
# Use dictionary comprehension to create a new dictionary that only includes students with marks >= 80.

students = {'Alice': 85, 'Bob': 60, 'Charlie': 95}

# Write your code here
