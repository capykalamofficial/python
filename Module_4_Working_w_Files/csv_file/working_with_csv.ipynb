# %% [markdown]
# ## Working with CSV files

# %%
# Problem 1
# Write a program that reads a comma-separated CSV file and prints each row (as a list of values).
# Use the file "sample.csv"

# Write your code here

# %%
# Problem 2
# Write a program that takes a 2D list (list of lists)and writes each sublist as a row to a CSV file "data.csv".

# Write your code here
