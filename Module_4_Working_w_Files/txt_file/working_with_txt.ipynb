# %% [markdown]
# ## Working with txt files

# %%
# Problem 1
# Write a program to read the number of lines in the "sample.txt" file provided in the same folder.

# Write your code here

# %%
# Problem 2
# Write a program to read the file "sample.txt" and print each line.
# Don't add extra newlines

# Write your code here

# %%
# Problem 3
# Write a program to write a list of string into a new file "data.txt".

# Write your code here

# %%
# Problem 4
# Write a program to count how many times each word appears in the given file "word_count.txt"
# Output : "apple":4, "banana":3, "orange":2

# Write your code here
